# %%
import json, pandas as pd

with open('dataframe_json.json','r') as f:
    data = f.read()
json_dict= eval(json.loads(data))
json_dataframe=(pd.DataFrame(json_dict)).transpose()
print json_dataframe.describe()#==csv_dataframe.describe()



#http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
csv_dataframe=pd.DataFrame.from_csv('dataframe_csv.csv')
#print csv_dataframe.describe()
    
#http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html   
excel_dataframe=pd.read_excel('dataframe_excel.xlsx',sheetname=0)
#print excel_dataframe.describe()#==csv_dataframe.describe()
# Out:
#        android_avg_rating  android_file_size  android_rating_1  \
# count         6192.000000        6192.000000       6192.000000
# mean             4.024806          67.943152     690972.132267
# std              0.081686           8.592706     280445.157067
# min              3.900000          58.000000     199974.000000
# 25%              4.000000          60.000000     295353.000000
# 50%              4.000000          61.000000     723090.000000
# 75%              4.100000          77.000000     949038.000000
# max              4.100000          77.000000     982631.000000
#
#        android_rating_2  android_rating_3  android_rating_4  android_rating_5  \
# count       6192.000000       6192.000000       6192.000000      6.192000e+03
# mean      211569.049096     389064.407138     621651.528908      3.111013e+06
# std        76286.212753     146345.208364     247401.832746      1.326894e+06
# min        71521.000000     117754.000000     165956.000000      7.265970e+05
# ...

# %%
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

#color_palette = {0: 'red', 1: 'yellow', 2: 'blue', 3:''}
#colors = [color_palette[c] for c in iris_target]
scatter_matrix(json_dataframe, figsize=(10,10))#, color=colors) #, diagonal='kde')
plt.suptitle('Scatter Matrix', size=20)
plt.savefig("scatter matrix.jpg")
plt.show()

# %%
import numpy as np

print "Correlation Coefficients"
print "android_rating_1 & android_rating_2:", np.corrcoef(json_dataframe.android_rating_1, json_dataframe.android_rating_2)[0][1]
print "android_rating_1 & android_rating_3:", np.corrcoef(json_dataframe.android_rating_1, json_dataframe.android_rating_3)[0][1]
print "android_rating_1 & android_rating_4:", np.corrcoef(json_dataframe.android_rating_1, json_dataframe.android_rating_4)[0][1]
print "android_rating_1 & android_rating_5:", np.corrcoef(json_dataframe.android_rating_1, json_dataframe.android_rating_5)[0][1]
print "android_rating_1 & android_total_ratings:", np.corrcoef(json_dataframe.android_rating_1, json_dataframe.android_total_ratings)[0][1]
print "android_rating_1 & ios_all_ratings:", np.corrcoef(json_dataframe.android_rating_1, json_dataframe.ios_all_ratings)[0][1]
print ("\n")

print "android_rating_2 & android_rating_3:", np.corrcoef(json_dataframe.android_rating_2, json_dataframe.android_rating_3)[0][1]
print "android_rating_2 & android_rating_4:", np.corrcoef(json_dataframe.android_rating_2, json_dataframe.android_rating_4)[0][1]
print "android_rating_2 & android_rating_5:", np.corrcoef(json_dataframe.android_rating_2, json_dataframe.android_rating_5)[0][1]
print "android_rating_2 & android_total_ratings:", np.corrcoef(json_dataframe.android_rating_2, json_dataframe.android_total_ratings)[0][1]
print "android_rating_2 & ios_all_ratings:", np.corrcoef(json_dataframe.android_rating_2, json_dataframe.ios_all_ratings)[0][1]
print ("\n")

print "android_rating_3 & android_rating_4:", np.corrcoef(json_dataframe.android_rating_3, json_dataframe.android_rating_4)[0][1]
print "android_rating_3 & android_rating_5:", np.corrcoef(json_dataframe.android_rating_3, json_dataframe.android_rating_5)[0][1]
print "android_rating_3 & android_total_ratings:", np.corrcoef(json_dataframe.android_rating_3, json_dataframe.android_total_ratings)[0][1]
print "android_rating_3 & ios_all_ratings:", np.corrcoef(json_dataframe.android_rating_3, json_dataframe.ios_all_ratings)[0][1]
print ("\n")

print "android_rating_4 & android_rating_5:", np.corrcoef(json_dataframe.android_rating_4, json_dataframe.android_rating_5)[0][1]
print "android_rating_4 & android_total_ratings:", np.corrcoef(json_dataframe.android_rating_4, json_dataframe.android_total_ratings)[0][1]
print "android_rating_4 & ios_all_ratings:", np.corrcoef(json_dataframe.android_rating_4, json_dataframe.ios_all_ratings)[0][1]
print ("\n")

print "android_rating_5 & android_total_ratings:", np.corrcoef(json_dataframe.android_rating_5, json_dataframe.android_total_ratings)[0][1]
print "android_rating_5 & ios_all_ratings:", np.corrcoef(json_dataframe.android_rating_5, json_dataframe.ios_all_ratings)[0][1]
print ("\n")

print "ios_all_ratings & android_total_ratings:", np.corrcoef(json_dataframe.ios_all_ratings, json_dataframe.android_total_ratings)[0][1]
print ("\n")

print "ios_file_size & ios _current_rating:", np.corrcoef(json_dataframe.ios_file_size,json_dataframe.ios_current_ratings)[0][1]
print "ios_all_ratings & ios _current_rating:", np.corrcoef(json_dataframe.ios_all_ratings,json_dataframe.ios_current_ratings)[0][1]
print "android_total_ratings & ios _current_rating:", np.corrcoef(json_dataframe.android_total_ratings,json_dataframe.ios_current_ratings)[0][1]
print "android_rating_5 & ios _current_rating:", np.corrcoef(json_dataframe.android_rating_5,json_dataframe.ios_current_ratings)[0][1]
print "android_rating_4 & ios _current_rating:", np.corrcoef(json_dataframe.android_rating_4,json_dataframe.ios_current_ratings)[0][1]
print "android_rating_3 & ios _current_rating:", np.corrcoef(json_dataframe.android_rating_3,json_dataframe.ios_current_ratings)[0][1]
print "android_rating_2 & ios _current_rating:", np.corrcoef(json_dataframe.android_rating_2,json_dataframe.ios_current_ratings)[0][1]
print "android_rating_1 & ios _current_rating:", np.corrcoef(json_dataframe.android_rating_1,json_dataframe.ios_current_ratings)[0][1]
print ("\n")


print "android_rating_1 & android_file_size:", np.corrcoef(json_dataframe.android_rating_1,json_dataframe.android_file_size)[0][1]
print "android_rating_2 & android_file_size:", np.corrcoef(json_dataframe.android_rating_2,json_dataframe.android_file_size)[0][1]
print "android_rating_3 & android_file_size:", np.corrcoef(json_dataframe.android_rating_3,json_dataframe.android_file_size)[0][1]
print "android_rating_4 & android_file_size:", np.corrcoef(json_dataframe.android_rating_4,json_dataframe.android_file_size)[0][1]
print "android_rating_5 & android_file_size:", np.corrcoef(json_dataframe.android_rating_5,json_dataframe.android_file_size)[0][1]
print "android_total_ratings & android_file_size:", np.corrcoef(json_dataframe.android_total_ratings,json_dataframe.android_file_size)[0][1]
print "ios_all_ratings & android_file_size:", np.corrcoef(json_dataframe.ios_all_ratings,json_dataframe.android_file_size)[0][1]
print "ios_current_ratings & android_file_size:", np.corrcoef(json_dataframe.ios_current_ratings,json_dataframe.android_file_size)[0][1]
print ("\n")

print "android_rating_1 & android_avg_rating:", np.corrcoef(json_dataframe.android_rating_1,json_dataframe.android_avg_rating)[0][1]
print "android_rating_2 & android_avg_rating:", np.corrcoef(json_dataframe.android_rating_2,json_dataframe.android_avg_rating)[0][1]
print "android_rating_3 & android_avg_rating:", np.corrcoef(json_dataframe.android_rating_3,json_dataframe.android_avg_rating)[0][1]
print "android_rating_4 & android_avg_rating:", np.corrcoef(json_dataframe.android_rating_4,json_dataframe.android_avg_rating)[0][1]
print "android_rating_5 & android_avg_rating:", np.corrcoef(json_dataframe.android_rating_5,json_dataframe.android_avg_rating)[0][1]
print "android_total_ratings & android_avg_rating:", np.corrcoef(json_dataframe.android_total_ratings,json_dataframe.android_avg_rating)[0][1]
print "ios_all_ratings & android_avg_rating:", np.corrcoef(json_dataframe.ios_all_ratings,json_dataframe.android_avg_rating)[0][1]
print "ios_current_ratings & android_avg_rating:", np.corrcoef(json_dataframe.ios_current_ratings,json_dataframe.android_avg_rating)[0][1]#,"Remove this........"
#print np.corrcoef(xs, ys2)[0][1]

print "ios_file_size & android_rating_5:", np.corrcoef(json_dataframe.ios_file_size,json_dataframe.android_rating_5)[0][1]
# Out:
# Correlation Coefficients
# android_rating_1 & android_rating_2: 0.996811624582
# android_rating_1 & android_rating_3: 0.996191931461
# android_rating_1 & android_rating_4: 0.996662221151
# android_rating_1 & android_rating_5: 0.996538793456
# android_rating_1 & android_total_ratings: 0.997430505627
# android_rating_1 & ios_all_ratings: 0.980637676808
#
#
# android_rating_2 & android_rating_3: 0.999958299076
# android_rating_2 & android_rating_4: 0.999925526871
# android_rating_2 & android_rating_5: 0.999803804551
# android_rating_2 & android_total_ratings: 0.999857644
# android_rating_2 & ios_all_ratings: 0.992785755211
#
#
# android_rating_3 & android_rating_4: 0.99994991574
# android_rating_3 & android_rating_5: 0.999815450006
# android_rating_3 & android_total_ratings: 0.999785704172
# android_rating_3 & ios_all_ratings: 0.993522681366
#
#
# android_rating_4 & android_rating_5: 0.99990449764
# android_rating_4 & android_total_ratings: 0.999907355918
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize = (20,5))
plt.suptitle('Android Average Ratings', size=20)
plt.ylabel('android_avg_rating', size=20)
plt.xlabel('Date and Time', size=20)
json_dataframe[json_dataframe.columns[0]].plot()#kind='density') # PDF
plt.legend(loc='best', prop={'size':20})
plt.grid(True)
plt.savefig('Android Average Ratings.jpg')
plt.show()

# %%
from matplotlib import *
import matplotlib.pyplot as plt

plt.figure(1, figsize = (20,5))
plt.suptitle('Android File Size', size=20)
plt.ylabel('android_file_size', size=20)
plt.xlabel('Date and Time', size=20)
plt.yticks( rotation='vertical')
json_dataframe[json_dataframe.columns[1]].plot()#kind='density') # PDF
plt.legend(loc='best', prop={'size':20})
plt.grid(True)
plt.savefig('Android File Size.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt



json_dataframe[json_dataframe.columns[2:8]].plot()#kind='density') # PDF
plt.figure(1, figsize = (30,5))
plt.suptitle('Summary of Android Average Ratings', size=15)
plt.xlabel('Date and Time', size=15, labelpad=20)
plt.ylabel('android_ratings', size=15)
#plt.grid(True)
#plt.legend()
#http://stackoverflow.com/questions/7125009/how-to-change-legend-size-with-matplotlib-pyplot
plt.legend(loc='best', prop={'size':10})
plt.grid(True)
plt.savefig('Summary of Android Average Ratings.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize = (19,5))
plt.suptitle('iOS All Ratings', size=20)
plt.ylabel('ios_all_ratings', size=20)
plt.xlabel('Date and Time', size=20)
json_dataframe[json_dataframe.columns[8]].plot()#kind='density') # PDF
plt.legend(loc='best', prop={'size':15})
plt.grid(True)
plt.savefig('iOS All Ratings.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize = (19,5))
plt.suptitle('iOS Current Ratings', size=20)
plt.ylabel('ios_current_ratings', size=20)
plt.xlabel('Date and Time', size=20)
json_dataframe[json_dataframe.columns[9]].plot()#kind='density') # PDF
plt.legend(loc='best', prop={'size':15})
plt.grid(True)
plt.savefig('iOS Current Ratings.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize = (19,5))
plt.suptitle('iOS File Size', size=20)
plt.ylabel('ios_file_size', size=20)
plt.xlabel('Date and Time', size=20)
json_dataframe[json_dataframe.columns[10]].plot()#kind='density') # PDF
plt.legend(loc='best', prop={'size':15})
plt.grid(True)
plt.savefig('iOS File Size.jpg')
plt.show()

# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.cross_validation import train_test_split

# %%
#For Android
y_android=pd.DataFrame(json_dataframe.android_total_ratings)

x1=json_dataframe.android_avg_rating
x2=json_dataframe.android_file_size
x3=json_dataframe.android_rating_1
x4=json_dataframe.android_rating_2
x5=json_dataframe.android_rating_3
x6=json_dataframe.android_rating_4
x7=json_dataframe.android_rating_5

#print type(x1)
#For iOS
y_ios=pd.DataFrame(json_dataframe.ios_all_ratings)

x8=json_dataframe.ios_current_ratings
x9=json_dataframe.ios_file_size


#print type(json_dataframe.android_file_size)
#print (x)

# %%
x_android_linear=pd.concat([x1,x3,x4,x7],axis=1)
x_ios_linear=pd.concat([x1,x2,x4,x5],axis=1)

# %%
linear_android=linear_model.LinearRegression()
linear_ios=linear_model.LinearRegression()

# %%
#Linear regression for Android

xa_train, xa_test, ya_train,  ya_test = train_test_split(x_android_linear,y_android, test_size=0.5, random_state=4)
linear_android.fit(xa_train, ya_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Linear regression for ios

xi_train, xi_test, yi_train,  yi_test = train_test_split(x_ios_linear,y_ios, test_size=0.5, random_state=4)
linear_ios.fit(xi_train, yi_train)
#print linear_ios.coef_
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print "Linear Regression Models\n"
#print "fgnm",reg.coef_[0][0],"fd",reg.intercept_[0]
print "linear_model_android=",linear_android.intercept_[0],"+",linear_android.coef_[0][0],"* android_avg_ratings +",linear_android.coef_[0][1],"* android_rating_1",linear_android.coef_[0][2],"* android_rating_2",linear_android.coef_[0][3],"* android_rating_5\n"

print "linear_model_ios=",linear_ios.intercept_[0],"+",linear_ios.coef_[0][0],"* android_avg_ratings +",linear_ios.coef_[0][1],"* android_file_size +",linear_ios.coef_[0][2],"* android_rating_2 +",linear_ios.coef_[0][3],"* android_rating_3"
# Out:
# Linear Regression Models
#
# linear_model_android= -246893.733687 + 49380.0288629 * android_avg_ratings + 1.04303462566 * android_rating_1 5.30700608698 * android_rating_2 1.03789695269 * android_rating_5
#
# linear_model_ios= -163230.880216 + 64326.2492232 * android_avg_ratings + -688.709348253 * android_file_size + 2.44646686496 * android_rating_2 + -0.959073489413 * android_rating_3

# %%
android_lin_pred=linear_android.predict(xa_test)
ios_lin_pred=linear_ios.predict(xi_test)
#print "android pred        iOS pred"
#for i in range(len(ya_test)):
#    print android_pred[i],ios_pred[i]

# %%
#Mean Square Error
MSE_lin_android=np.mean((android_lin_pred-ya_test)**2)/len(android_lin_pred)
MSE_lin_ios=np.mean((ios_lin_pred-yi_test)**2)/len(ios_lin_pred)
print "Mean Square Errors: For Linear Model"
print "\nMSE of Android= ", MSE_lin_android[0],'\n'
print "MSE of iOS= ", MSE_lin_ios[0],'\n'
# Out:
# Mean Square Errors: For Linear Model
#
# MSE of Android=  2121.19761373
#
# MSE of iOS=  583.356704212

# %%
#R-squared value
from sklearn.metrics import r2_score

print "R2-Values: For Linear Model"

COD_android_lin = r2_score(ya_test, android_lin_pred)
print "\nR2-Value for Android= ",COD_android_lin,'\n'

COD_ios_lin = r2_score(yi_test, ios_lin_pred)
print "R2-Value for iOS= ",COD_ios_lin,'\n'
# Out:
# R2-Values: For Linear Model
#
# R2-Value for Android=  0.999998463124
#
# R2-Value for iOS=  0.999118718784

# %% [markdown]
# # Ridge

# %%
x_android_ridge=pd.concat([x1,x3,x4,x7],axis=1)
x_ios_ridge=pd.concat([x1,x2,x4,x5],axis=1)

# %%
#Linear regression for Android

xa_train, xa_test, ya_train,  ya_test = train_test_split(x_android_ridge,y_android, test_size=0.5, random_state=4)
linear_android.fit(xa_train, ya_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Linear regression for ios

xi_train, xi_test, yi_train,  yi_test = train_test_split(x_ios_ridge,y_ios, test_size=0.5, random_state=4)
linear_ios.fit(xi_train, yi_train)
#print linear_ios.coef_
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.linear_model import Ridge

#Ridge Model for Android
ridge_android = Ridge(alpha = .5)
ridge_android.fit(xa_train, ya_train)

android_ridge_pred=ridge_android.predict(xa_test)
#print android_ridge_pred[0]


#Ridge Model for iOS
ridge_ios = Ridge(alpha = .5)
ridge_ios.fit(xi_train, yi_train)

ios_ridge_pred=ridge_ios.predict(xi_test)
#print ios_ridge_pred[0]

# %%
print "Ridge Regression Models\n"

print "ridge_model_android=",ridge_android.intercept_[0],"+",ridge_android.coef_[0][0],"*android_avg_ratings +",ridge_android.coef_[0][1],"*android_rating_1",ridge_android.coef_[0][2],"*android_rating_2",ridge_android.coef_[0][3],"*android_rating_5\n"

print "ridge_model_android=",ridge_ios.intercept_[0],"+",ridge_ios.coef_[0][0],"*android_avg_ratings +",ridge_ios.coef_[0][1],"*android_file_size",ridge_ios.coef_[0][2],"*android_rating_2",ridge_ios.coef_[0][3],"*android_rating_3"
# Out:
# Ridge Regression Models
#
# ridge_model_android= -183372.285635 + 34785.6858028 *android_avg_ratings + 1.01516114886 *android_rating_1 5.12980831411 *android_rating_2 1.05460171748 *android_rating_5
#
# ridge_model_android= -128811.683528 + 56577.4442571 *android_avg_ratings + -701.163395589 *android_file_size 2.01048776955 *android_rating_2 -0.728118080007 *android_rating_3

# %%
#Mean Square Error
MSE_ridge_android=np.mean((android_ridge_pred-ya_test)**2)/len(android_ridge_pred)
MSE_ridge_ios=np.mean((ios_ridge_pred-yi_test)**2)/len(ios_ridge_pred)

print "Mean Square Errors: For Ridge Model"
print "\nMSE of Android= ", MSE_ridge_android[0],'\n'
print "MSE of iOS= ", MSE_ridge_ios[0],'\n'
# Out:
# Mean Square Errors: For Ridge Model
#
# MSE of Android=  2145.56066984
#
# MSE of iOS=  595.274043069

# %%
#R-squared value
from sklearn.metrics import r2_score

print "R2-Values: For Ridge Model"

COD_android_ridge = r2_score(ya_test, android_ridge_pred)
print "\nR2-Value for Android= ",COD_android_ridge,'\n'

COD_ios_ridge = r2_score(yi_test, ios_ridge_pred)
print "R2-Value for iOS= ",COD_ios_ridge,'\n'
# Out:
# R2-Values: For Ridge Model
#
# R2-Value for Android=  0.999998445472
#
# R2-Value for iOS=  0.999100715174

# %% [markdown]
# # Lasso

# %%
x_android_lasso=pd.concat([x1,x3,x7,x9],axis=1)
x_ios_lasso=pd.concat([x1,x2,x4,x5],axis=1)

# %%
#Linear regression for Android

xa_train, xa_test, ya_train,  ya_test = train_test_split(x_android_lasso,y_android, test_size=0.5, random_state=4)
linear_android.fit(xa_train, ya_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Linear regression for ios

xi_train, xi_test, yi_train,  yi_test = train_test_split(x_ios_lasso,y_ios, test_size=0.5, random_state=4)
linear_ios.fit(xi_train, yi_train)
#print linear_ios.coef_
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.linear_model import Lasso

lasso_android = Lasso(alpha=0.1)

lasso_for_r2_a=lasso_android.fit(xa_train, ya_train).predict(xa_test)
r2_score_lasso_a = r2_score(ya_test, lasso_for_r2_a)
android_lasso_pred=lasso_android.predict(xa_test)
#print android_lasso_pred[3]

#print lasso_android.coef_

lasso_ios = Lasso(alpha=0.1)
lasso_for_r2_i=lasso_ios.fit(xi_train, yi_train).predict(xi_test)
r2_score_lasso_i = r2_score(yi_test, lasso_for_r2_i)
ios_lasso_pred=lasso_ios.predict(xi_test)
#print ios_lasso_pred[6]
# Out:
# C:\Users\Vidya\Anaconda2\lib\site-packages\sklearn\linear_model\coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)

# %%
print "Lasso Regression Models\n"

print "lasso_model_android=",lasso_android.intercept_[0],"+",lasso_android.coef_[0],"* android_avg_ratings +",lasso_android.coef_[1],"* android_rating_1 +",lasso_android.coef_[2],"* android_rating_5 +",lasso_android.coef_[3],"* ios_file_size\n"

print "lasso_model_ios=",lasso_ios.intercept_[0],"+",lasso_ios.coef_[0],"* android_avg_ratings +",lasso_ios.coef_[1],"* android_file_size +",lasso_ios.coef_[2],"* android_rating_2 +",lasso_ios.coef_[3],"* android_rating_3"
# Out:
# Lasso Regression Models
#
# lasso_model_android= -2166041.76067 + 576551.149822 * android_avg_ratings + 2.92505370177 * android_rating_1 + 0.94127144775 * android_rating_5 + -403.850059563 * ios_file_size
#
# lasso_model_ios= -98765.8336905 + 50772.3583151 * android_avg_ratings + -613.745669494 * android_file_size + 0.659664109322 * android_rating_2 + -0.0259880377082 * android_rating_3

# %%
#Mean Square Error
import numpy as np
android_lasso_predT=android_lasso_pred[:,None]
ios_lasso_predT=ios_lasso_pred[:,None]

MSE_lasso_android=np.mean((android_lasso_predT-ya_test)**2)/len(android_lasso_predT)
MSE_lasso_ios=np.mean((ios_lasso_predT-yi_test)**2)/len(ios_lasso_predT)

print "Mean Square Errors: For lasso Model"
print "\nMSE of Android= ", MSE_lasso_android[0],'\n'
print "MSE of iOS= ", MSE_lasso_ios[0],'\n'
# Out:
# Mean Square Errors: For lasso Model
#
# MSE of Android=  150801.804919
#
# MSE of iOS=  676.33121866

# %%
from sklearn.metrics import r2_score

print "R2-Values: For Lasso Model"


COD_android_lasso= r2_score(ya_test, android_lasso_pred)
print "\nR2-Value for Android= ",COD_android_lasso,'\n'


COD_ios_lasso = r2_score(yi_test, ios_lasso_pred)
print "R2-Value for iOS= ",COD_ios_lasso,'\n'
# Out:
# R2-Values: For Lasso Model
#
# R2-Value for Android=  0.999890739254
#
# R2-Value for iOS=  0.998978261509

# %% [markdown]
# # Forecasting Xs

# %%
#https://analysights.wordpress.com/tag/smoothing-constant/
#Forecasting of X values using Smoothing Constant Method for prediction of Y
def forecast(actual):
    #actual=act
    req=[]
    for i in range(1,720,24):
        req.append(actual[-i])
    forecasted=[req[0]]
    for i in range(len(req)):
        forecasted.append(0.8*req[i]+0.2*forecasted[i])
    return forecasted

x1_p=json_dataframe.android_avg_rating
x2_p=json_dataframe.android_file_size
x3_p=json_dataframe.android_rating_1
x4_p=json_dataframe.android_rating_2
x5_p=json_dataframe.android_rating_3
x6_p=json_dataframe.android_rating_4
x7_p=json_dataframe.android_rating_5
x8_p=json_dataframe.ios_current_ratings
x9_p=json_dataframe.ios_file_size


#Forecasted X values
x1_pred=forecast(x1_p)
x2_pred=forecast(x2_p)
x3_pred=forecast(x3_p)
x4_pred=forecast(x4_p)
x5_pred=forecast(x5_p)
x6_pred=forecast(x6_p)
x7_pred=forecast(x7_p)
x8_pred=forecast(x8_p)
x9_pred=forecast(x9_p)
#print x1_pred,x2_pred,x3_pred,x4_pred,x5_pred,x6_pred,x7_pred,x8_pred,x9_pred

# %% [markdown]
# # Predictions using linear Model

# %%
android_final_pred=384182.060655 -55936.3319478 *x1_pred[1]-1040.45381479*x2_pred[1]+1.14666392932*x3_pred[1]+1.33136637837* x7_pred[1]
print "Predictions for 2016/11/01 11:50 PM using Linear Model"
print "Android Prediction: ",android_final_pred #,json_dataframe.android_total_ratings[-2],"\n"



ios_final_pred= 62787.6518253 + 2.3577903919 * x4_pred[1]  -0.765664091132 * x5_pred[1]  -0.0745145709177 * x6_pred[1]  -109.427540569  * x9_pred[1]
print "iOS Prediction: ", ios_final_pred#,json_dataframe.ios_all_ratings[-2]
# Out:
# Predictions for 2016/11/01 11:50 PM using Linear Model
# Android Prediction:  7001939.99562
# iOS Prediction:  238090.330747

# %%
#Errors (Timepass)
#print (json_dataframe.android_total_ratings[-2]-android_final_pred)/json_dataframe.android_total_ratings[-2],"\n"
#print (json_dataframe.ios_all_ratings[-2]-ios_final_pred)/json_dataframe.ios_all_ratings[-2]

# %% [markdown]
# # Prediction using Ridge Model

# %%
ridge_model_android= 258690.342634 -59228.3571872 *x1_pred[0] + 0.86989974555 *x3_pred[0]+ 2.77284413237 *x4_pred[0] +1.22593036947 *x7_pred[0]
print "Predictions for 2016/11/01 11:50 PM using Ridge Model"
print "Android Prediction: ",ridge_model_android
ridge_model_ios= -185981.830786 + 67460.9314929 *x1_pred[0] -576.749856743 *x2_pred[0]+ 3.61701182707 *x4_pred[0] -1.58600552805 *x5_pred[0]
print "iOS Prediction: ",ridge_model_ios
# Out:
# Predictions for 2016/11/01 11:50 PM using Ridge Model
# Android Prediction:  7003099.47752
# iOS Prediction:  232215.978683

# %%
#Errors (Timepass)
#print (json_dataframe.android_total_ratings[-1]-ridge_model_android)/json_dataframe.android_total_ratings[-1],"\n"
#print (json_dataframe.ios_all_ratings[-1]-ridge_model_ios)/json_dataframe.ios_all_ratings[-1]

# %% [markdown]
# # Lasso Model

# %%
lasso_model_android= 337396.585788  -55546.3619183 * x1_pred[0] + 1.02771776825 * x3_pred[0] + 1.35224462187 * x7_pred[0]  -41.5810248656 * x9_pred[0]
print "Predictions for 2016/11/01 11:50 PM using Ridge Model"
print "Android Prediction: ", lasso_model_android
lasso_model_ios= -155855.333291 + 62572.9731236 * x1_pred[0]  -491.747809921 * x2_pred[0]  + 2.39351747802 * x4_pred[0]  -0.960161544314 * x5_pred[0]
print "iOS Prediction: ", lasso_model_ios


#lasso_model_ios= -155855.333291 + 62572.9731236 * android_avg_ratings + -491.747809921 * android_file_size + 2.39351747802 * android_rating_2 + -0.960161544314 * android_rating_3
# Out:
# Predictions for 2016/11/01 11:50 PM using Ridge Model
# Android Prediction:  7000053.7738
# iOS Prediction:  231374.787206

# %%
#Errors (Timepass)
#print (json_dataframe.android_total_ratings[-1]-lasso_model_android)/json_dataframe.android_total_ratings[-1],"\n"
#print (json_dataframe.ios_all_ratings[-1]-lasso_model_ios)/json_dataframe.ios_all_ratings[-1]
